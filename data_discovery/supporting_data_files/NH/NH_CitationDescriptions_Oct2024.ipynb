# %% [markdown]
# ## NH Supporting File
#
#
# __NH_CitationDescriptions_Oct2024.csv__

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
import os

# Get the directory of the current file
current_dir = os.path.dirname(os.getcwd())

# Get the parent directory path
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))

# Add directory to sys.path
sys.path.insert(0, parent_dir)

import quality_check as qc

# %% [markdown]
# # Description
#
#
# This is a look-up table for nursing home inspection citations, providing a text description for each citation or tag code.
#
#
# The primary key is Deficiency Prefix and Number.

# %% [markdown]
# ## Data Dictionary
#
# | Variable Name (Column Header) | Description | Variable Type |
# |---|---|---|
# | Deficiency Prefix | Deficiency Prefix (F, K, E) | Text (1) |
# | Deficiency Tag Number | Deficiency Tag Number | Numeric |
# | Deficiency Prefix and Number | Deficiency Prefix and Number (e.g., F-0880) | Text (6) |
# | Deficiency Description | Deficiency Description | Text |
# | Deficiency Category | Category Description for Care Compare website | Text |

# %%
file_path = qc.supporting_files_path + 'NH_CitationDescriptions_Oct2024.csv'
df, profile_df, numeric_summary = qc.analyze_csv_data_quality(file_path)
# Out:
# Loaded file successfully with encoding: utf-8
#
# ...
# DATASET OVERVIEW
# ...
# File: NH_CitationDescriptions_Oct2024.csv
# Rows: 641
# Columns: 5
#
# ...
# COLUMN NAMES AND DATA TYPES
# ...
#                  column_name  dtype
#            Deficiency Prefix object
#        Deficiency Tag Number  int64
# Deficiency Prefix and Number object
#       Deficiency Description object
#          Deficiency Category object
#
# ...
# DATASET-LEVEL QUALITY METRICS
# ...
# Duplicate rows: 0 (0.00%)
#
# ...
# COLUMN-LEVEL DATA QUALITY SUMMARY
# ...
#                  column_name  dtype  row_count  non_null_count  missing_count  missing_pct  completeness_pct  unique_non_null_values  constant_column_flag  high_missing_flag possible_type_issue
#            Deficiency Prefix object        641             641              0          0.0             100.0                       3                 False              False
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(profile_df)
# Out:
#                     column_name   dtype  row_count  non_null_count  \
# 0             Deficiency Prefix  object        641             641
# 1         Deficiency Tag Number   int64        641             641
# 2  Deficiency Prefix and Number  object        641             641
# 3        Deficiency Description  object        641             641
# 4           Deficiency Category  object        641             641
#
#    missing_count  missing_pct  completeness_pct  unique_non_null_values  \
# 0              0          0.0             100.0                       3
# 1              0          0.0             100.0                     549
# 2              0          0.0             100.0                     641
# 3              0          0.0             100.0                     589
# 4              0          0.0             100.0                      28
#
#    constant_column_flag  high_missing_flag possible_type_issue
# 0                 False              False
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(numeric_summary)
# Out:
#              column_name  count        mean          std  min    25%    50%  \
# 0  Deficiency Tag Number  641.0  613.107644  1150.902397  1.0  223.0  465.0
#
#      75%     max
# 0  731.0  9211.0
