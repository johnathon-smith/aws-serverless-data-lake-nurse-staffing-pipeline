# %% [markdown]
# ## NH Supporting File
#
#
# __NH_CovidVaxAverages_20241027.csv__

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
import os

# Get the directory of the current file
current_dir = os.path.dirname(os.getcwd())

# Get the parent directory path
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))

# Add directory to sys.path
sys.path.insert(0, parent_dir)

import quality_check as qc

# %% [markdown]
# # Description
#
#
# State and National averages for facility resident and healthcare personnel COVID-19 vaccination rates. Data are presented as one row per state or territory plus a row for national averages.
#
#
# The primary key is State.

# %% [markdown]
# ## Data Dictionary
#
# | Variable Name (Column Header) | Description | Variable Type |
# |---|---|---|
# | State | State postal abbreviation | Text (2) |
# | Percent of residents who are up to date on COVID-19 vaccinations | Percentage of residents who are up to date with COVID-19 vaccinations | Numeric |
# | Percent of healthcare personnel who are up to date on COVID-19 vaccinations | Percentage of healthcare personnel who are up to date with COVID-19 vaccinations | Numeric |
# | Week Ending | The date corresponding to the end of the reporting week | Date |
# | Processing Date | Date the data were retrieved | Date |

# %%
file_path = qc.supporting_files_path + 'NH_CovidVaxAverages_20241027.csv'
df, profile_df, numeric_summary = qc.analyze_csv_data_quality(file_path)
# Out:
# Loaded file successfully with encoding: utf-8
#
# ...
# DATASET OVERVIEW
# ...
# File: NH_CovidVaxAverages_20241027.csv
# Rows: 54
# Columns: 4
#
# ...
# COLUMN NAMES AND DATA TYPES
# ...
#                                               column_name   dtype
#                                                     State  object
# Percent of residents who are up-to-date on their vaccines float64
#     Percent of staff who are up-to-date on their vaccines float64
#                        Date vaccination data last updated  object
#
# ...
# DATASET-LEVEL QUALITY METRICS
# ...
# Duplicate rows: 0 (0.00%)
#
# ...
# COLUMN-LEVEL DATA QUALITY SUMMARY
# ...
#                                               column_name   dtype  row_count  non_null_count  missing_count  missing_pct  completeness_pct  unique_non_null_values  constant_column_flag  high_missing_flag possible_type_issue
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(profile_df)
# Out:
#                                          column_name    dtype  row_count  \
# 0                                              State   object         54
# 1  Percent of residents who are up-to-date on the...  float64         54
# 2  Percent of staff who are up-to-date on their v...  float64         54
# 3                 Date vaccination data last updated   object         54
#
#    non_null_count  missing_count  missing_pct  completeness_pct  \
# 0              54              0          0.0             100.0
# 1              54              0          0.0             100.0
# 2              54              0          0.0             100.0
# 3              54              0          0.0             100.0
#
#    unique_non_null_values  constant_column_flag  high_missing_flag  \
# 0                      54                 False              False
# 1                      45                 False              False
# 2                      40                 False              False
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(numeric_summary)
# Out:
#                                          column_name  count       mean  \
# 0  Percent of residents who are up-to-date on the...   54.0  26.538889
# 1  Percent of staff who are up-to-date on their v...   54.0   6.377778
#
#         std   min   25%    50%     75%   max
# 0  8.951724  10.9  20.9  24.35  30.650  62.6
# 1  5.277316   1.3   3.8   5.20   7.275  34.5
