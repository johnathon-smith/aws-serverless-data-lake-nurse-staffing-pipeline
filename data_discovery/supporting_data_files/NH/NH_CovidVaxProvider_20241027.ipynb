# %% [markdown]
# ## NH Supporting File
#
#
# __NH_CovidVaxProvider_20241027.csv__

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
import os

# Get the directory of the current file
current_dir = os.path.dirname(os.getcwd())

# Get the parent directory path
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))

# Add directory to sys.path
sys.path.insert(0, parent_dir)

import quality_check as qc

# %% [markdown]
# # Description
#
#
# Current resident and healthcare personnel COVID-19 vaccination rates. Data are presented as one row per provider.
#
#
# The primary key is CMS Certification Number (CCN).

# %% [markdown]
# ## Data Dictionary
#
# | Variable Name (Column Header) | Description | Variable Type |
# |---|---|---|
# | CMS Certification Number (CCN) | CMS Certification Number (CCN) | Text (6) |
# | Provider Name | Provider Name | Text |
# | Provider Address | Provider Street Address | Text |
# | City/Town | Provider City/Town | Text |
# | State | Provider State – postal abbreviation | Text (2) |
# | ZIP Code | Provider Zip Code | Numeric |
# | Percent of residents who are up to date on COVID-19 vaccinations | Percentage of residents who are up to date with COVID-19 vaccinations | Numeric |
# | Percent of healthcare personnel who are up to date on COVID-19 vaccinations | Percentage of healthcare personnel who are up to date with COVID-19 vaccinations | Numeric |
# | Week Ending | The date corresponding to the end of the reporting week | Date |
# | Location | Location of facility (provider address, city, state, zip) | Text |
# | Processing Date | Date the data were retrieved | Date |

# %%
file_path = qc.supporting_files_path + 'NH_CovidVaxProvider_20241027.csv'
df, profile_df, numeric_summary = qc.analyze_csv_data_quality(file_path)
# Out:
# Loaded file successfully with encoding: utf-8
#
# ...
# DATASET OVERVIEW
# ...
# File: NH_CovidVaxProvider_20241027.csv
# Rows: 14814
# Columns: 5
#
# ...
# COLUMN NAMES AND DATA TYPES
# ...
#                                               column_name  dtype
#                            CMS Certification Number (CCN) object
#                                                     State object
# Percent of residents who are up-to-date on their vaccines object
#     Percent of staff who are up-to-date on their vaccines object
#                        Date vaccination data last updated object
#
# ...
# DATASET-LEVEL QUALITY METRICS
# ...
# Duplicate rows: 0 (0.00%)
#
# ...
# COLUMN-LEVEL DATA QUALITY SUMMARY
# ...
#                                               column_name  dtype  row_count  non_null_count  missing_count  missing_pct  completeness_pct  unique_non_null_values  constant_column_flag  high_missing_flag                    possible_type_issue
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(profile_df)
# Out:
#                                          column_name   dtype  row_count  \
# 0                     CMS Certification Number (CCN)  object      14814
# 1                                              State  object      14814
# 2  Percent of residents who are up-to-date on the...  object      14814
# 3  Percent of staff who are up-to-date on their v...  object      14814
# 4                 Date vaccination data last updated  object      14814
#
#    non_null_count  missing_count  missing_pct  completeness_pct  \
# 0           14814              0          0.0             100.0
# 1           14814              0          0.0             100.0
# 2           14814              0          0.0             100.0
# 3           14814              0          0.0             100.0
# 4           14814              0          0.0             100.0
#
#    unique_non_null_values  constant_column_flag  high_missing_flag  \
# 0                   14814                 False              False
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(numeric_summary)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
