# %% [markdown]
# ## NH Supporting File
#
#
# __NH_DataCollectionIntervals_Oct2024.csv__

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
import os

# Get the directory of the current file
current_dir = os.path.dirname(os.getcwd())

# Get the parent directory path
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))

# Add directory to sys.path
sys.path.insert(0, parent_dir)

import quality_check as qc

# %% [markdown]
# # Description
#
#
# This table lists the data collection periods for the quality measures displayed for Nursing Homes including Rehab Services as well as the intervals for complaint citations and citations on focused infection control inspections. It also includes the data collection period for the nursing home staffing measures. The data collection periods for some short-stay measures differ slightly from the measure periods in the MDS Quality Measure file due to the look-back periods for these measures.
#
#
# The primary key is Measure Code.
#
# I'm not sure if we need this file because the only relevant row is for Staffing Levels and all it indicates is that the staffing level collection period was from 2024-04-01 to 2024-06-30 (Q2 of 2024).

# %% [markdown]
# ## Data Dictionary
#
# | Variable Name (Column Header) | Description | Variable Type |
# |---|---|---|
# | Measure Code | Numeric code assigned to each quality measure (internal code for complaint intervals) | Text |
# | Measure Description | Measure Description | Text |
# | Data Collection Period From Date | Data Collection Period From Date | Date |
# | Data Collection Period Through Date | Data Collection Period Through Date | Date |
# | Measure Date Range | Measure Date Range; allows for a gap in the data collection period | Text |
# | Processing Date | Date the data were retrieved | Date |

# %%
file_path = qc.supporting_files_path + 'NH_DataCollectionIntervals_Oct2024.csv'
df, profile_df, numeric_summary = qc.analyze_csv_data_quality(file_path)
# Out:
# Loaded file successfully with encoding: utf-8
#
# ...
# DATASET OVERVIEW
# ...
# File: NH_DataCollectionIntervals_Oct2024.csv
# Rows: 45
# Columns: 6
#
# ...
# COLUMN NAMES AND DATA TYPES
# ...
#                         column_name   dtype
#                        Measure Code  object
#                 Measure Description  object
#    Data Collection Period From Date  object
# Data Collection Period Through Date  object
#                  Measure Date Range float64
#                     Processing Date   int64
#
# ...
# DATASET-LEVEL QUALITY METRICS
# ...
# Duplicate rows: 0 (0.00%)
#
# ...
# COLUMN-LEVEL DATA QUALITY SUMMARY
# ...
#                         column_name   dtype  row_count  non_null_count  missing_count  missing_pct  completeness_pct  unique_non_null_values  constant_column_flag  high_missing_flag possible_type_issue
#                        Measure Code  object         45              45              0          0.0             100.0                      45                 False              False
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(profile_df)
# Out:
#                            column_name    dtype  row_count  non_null_count  \
# 0                         Measure Code   object         45              45
# 1                  Measure Description   object         45              45
# 2     Data Collection Period From Date   object         45              45
# 3  Data Collection Period Through Date   object         45              45
# 4                   Measure Date Range  float64         45               0
# 5                      Processing Date    int64         45              45
#
#    missing_count  missing_pct  completeness_pct  unique_non_null_values  \
# 0              0          0.0             100.0                      45
# 1              0          0.0             100.0                      45
# 2              0          0.0             100.0                       8
# 3              0          0.0             100.0                       6
# 4             45        100.0               0.0                       0
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(numeric_summary)
# Out:
#           column_name  count        mean  std         min         25%  \
# 0  Measure Date Range    0.0         NaN  NaN         NaN         NaN
# 1     Processing Date   45.0  20241001.0  0.0  20241001.0  20241001.0
#
#           50%         75%         max
# 0         NaN         NaN         NaN
# 1  20241001.0  20241001.0  20241001.0

# %%
qc.check_duplicate_keys(df, ['Measure Code'])
# Out:
# Duplicate key rows: 0
# Empty DataFrame
# Columns: [Measure Code, Measure Description, Data Collection Period From Date, Data Collection Period Through Date, Measure Date Range, Processing Date]
# Index: []
