# %% [markdown]
# ## NH Supporting File
#
#
# __NH_HlthInspecCutpointsState_Oct2024.csv__

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
import os

# Get the directory of the current file
current_dir = os.path.dirname(os.getcwd())

# Get the parent directory path
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))

# Add directory to sys.path
sys.path.insert(0, parent_dir)

import quality_check as qc

# %% [markdown]
# # Description
#
#
# State-specific ranges for the weighted health inspection score for each health inspection star rating category. Data are presented as one row per state or territory.
#
#
# The primary key is State.

# %% [markdown]
# ## Data Dictionary
#
# | Variable Name (Column Header) | Description | Variable Type |
# |---|---|---|
# | State | State postal abbreviation | Text (2) |
# | 5 Stars | Cut point range to obtain a 5-star health inspection score within a specific state | Text |
# | 4 Stars | Cut point range to obtain a 4-star health inspection score within a specific state | Text |
# | 3 Stars | Cut point range to obtain a 3-star health inspection score within a specific state | Text |
# | 2 Stars | Cut point range to obtain a 2-star health inspection score within a specific state | Text |
# | 1 Star | Cut point range to obtain a 1-star health inspection score within a specific state | Text |

# %%
file_path = qc.supporting_files_path + 'NH_HlthInspecCutpointsState_Oct2024.csv'
df, profile_df, numeric_summary = qc.analyze_csv_data_quality(file_path)
# Out:
# Loaded file successfully with encoding: utf-8
#
# ...
# DATASET OVERVIEW
# ...
# File: NH_HlthInspecCutpointsState_Oct2024.csv
# Rows: 53
# Columns: 6
#
# ...
# COLUMN NAMES AND DATA TYPES
# ...
# column_name  dtype
#       State object
#     5 Stars object
#     4 Stars object
#     3 Stars object
#     2 Stars object
#      1 Star object
#
# ...
# DATASET-LEVEL QUALITY METRICS
# ...
# Duplicate rows: 0 (0.00%)
#
# ...
# COLUMN-LEVEL DATA QUALITY SUMMARY
# ...
# column_name  dtype  row_count  non_null_count  missing_count  missing_pct  completeness_pct  unique_non_null_values  constant_column_flag  high_missing_flag possible_type_issue
#       State object         53              53              0          0.0             100.0                      53                 False              False
#     5 Stars object         53              53              0          0.0             100.0                      34                 False              False
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(profile_df)
# Out:
#   column_name   dtype  row_count  non_null_count  missing_count  missing_pct  \
# 0       State  object         53              53              0          0.0
# 1     5 Stars  object         53              53              0          0.0
# 2     4 Stars  object         53              53              0          0.0
# 3     3 Stars  object         53              53              0          0.0
# 4     2 Stars  object         53              53              0          0.0
# 5      1 Star  object         53              53              0          0.0
#
#    completeness_pct  unique_non_null_values  constant_column_flag  \
# 0             100.0                      53                 False
# 1             100.0                      34                 False
# 2             100.0                      53                 False
# 3             100.0                      52                 False
# 4             100.0                      53                 False
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(numeric_summary)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
