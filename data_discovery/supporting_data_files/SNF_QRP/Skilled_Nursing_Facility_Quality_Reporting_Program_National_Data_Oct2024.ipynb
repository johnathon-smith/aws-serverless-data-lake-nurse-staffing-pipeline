# %% [markdown]
# ## NH Supporting File
#
#
# __Skilled_Nursing_Facility_Quality_Reporting_Program_National_Data_Oct2024.csv__

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
import os

# Get the directory of the current file
current_dir = os.path.dirname(os.getcwd())

# Get the parent directory path
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))

# Add directory to sys.path
sys.path.insert(0, parent_dir)

import quality_check as qc

# %% [markdown]
# # Description
#
#
# Skilled Nursing Facilities (SNFs) provide Medicare Part A SNF services to beneficiaries and must report data on certain measures of quality to Medicare through the Skilled Nursing Facility Quality Reporting Program (SNF QRP). This file contains national averages on quality measures implemented under the IMPACT Act.
#
#
# The primary key is Measure Code.

# %% [markdown]
# ## Data Dictionary
#
# | Variable Name (Column Header) | Description | Variable Type |
# |---|---|---|
# | CMS Certification Number (CCN) | The CMS certification number (CCN) is used to identify the facility listed. However, since this is the national data set, the CCN is listed as “Nation.” | Text (6) |
# | Measure Code | The measure code consists of the CMS ID (prefix) and the variable name (suffix) for the corresponding measure score. Example = S_038_02_NATL_OBS_RATE. Prefix: S_038_02. Suffix: NATL_OBS_RATE. See Table 22 for a complete listing of national data measure codes. | Text |
# | Score | The measure score for the corresponding measure code. | Text |
# | Footnote | Indicates the relevant footnote. Currently, there are no footnotes related to the national data. | Numeric |
# | Start Date | The start date of the reporting period for the corresponding measure code and score. | Date |
# | End Date | The end date of the reporting period for the corresponding measure code and score. | Date |
# | Measure Date Range | The start date through the end date of the reporting period(s) for the corresponding measure code and score. Note: Only reporting periods that are “split” are populated and represented by the use of a semicolon between the split periods (e.g., 04/01/2019-12/31/2019; 07/01/2020-09/30/2021). | Text |

# %%
file_path = qc.supporting_files_path + 'Skilled_Nursing_Facility_Quality_Reporting_Program_National_Data_Oct2024.csv'
df, profile_df, numeric_summary = qc.analyze_csv_data_quality(file_path)
# Out:
# Loaded file successfully with encoding: utf-8
#
# ...
# DATASET OVERVIEW
# ...
# File: Skilled_Nursing_Facility_Quality_Reporting_Program_National_Data_Oct2024.csv
# Rows: 24
# Columns: 7
#
# ...
# COLUMN NAMES AND DATA TYPES
# ...
#                    column_name   dtype
# CMS Certification Number (CCN)  object
#                   Measure Code  object
#                          Score float64
#                       Footnote float64
#                     Start Date  object
#                       End Date  object
#             Measure Date Range float64
#
# ...
# DATASET-LEVEL QUALITY METRICS
# ...
# Duplicate rows: 0 (0.00%)
#
# ...
# COLUMN-LEVEL DATA QUALITY SUMMARY
# ...
#                    column_name   dtype  row_count  non_null_count  missing_count  missing_pct  completeness_pct  unique_non_null_values  constant_column_flag  high_missing_flag possible_type_issue
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(profile_df)
# Out:
#                       column_name    dtype  row_count  non_null_count  \
# 0  CMS Certification Number (CCN)   object         24              24
# 1                    Measure Code   object         24              24
# 2                           Score  float64         24              24
# 3                        Footnote  float64         24               0
# 4                      Start Date   object         24              24
# 5                        End Date   object         24              24
# 6              Measure Date Range  float64         24               0
#
#    missing_count  missing_pct  completeness_pct  unique_non_null_values  \
# 0              0          0.0             100.0                       1
# 1              0          0.0             100.0                      24
# 2              0          0.0             100.0                      23
# 3             24        100.0               0.0                       0
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(numeric_summary)
# Out:
#           column_name  count         mean          std  min      25%   50%  \
# 0               Score   24.0  1882.060417  3603.394331  0.8  36.3775  93.0
# 1            Footnote    0.0          NaN          NaN  NaN      NaN   NaN
# 2  Measure Date Range    0.0          NaN          NaN  NaN      NaN   NaN
#
#        75%      max
# 0  1897.25  12962.0
# 1      NaN      NaN
# 2      NaN      NaN
