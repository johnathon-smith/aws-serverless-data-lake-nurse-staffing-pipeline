# %% [markdown]
# ## NH Supporting File
#
#
# __FY_2024_SNF_VBP_Aggregate_Performance.csv__

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
import os

# Get the directory of the current file
current_dir = os.path.dirname(os.getcwd())

# Get the parent directory path
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))

# Add directory to sys.path
sys.path.insert(0, parent_dir)

import quality_check as qc

# %% [markdown]
# # Description
#
#
# This table contains national, aggregate-level results for the fiscal year (FY) 2024 Skilled Nursing Facility Value-Based Purchasing (SNF VBP) Program. Included are unadjusted national average readmission rates for the baseline period (FY 2019) and performance period (FY 2022), the achievement threshold and benchmark (that is, the performance standards for the FY 2024 SNF VBP Program year), and information on performance scores, incentive payment multipliers, value-based incentive payments (in dollars), and the total number of SNFs receiving value-based incentive payments for the FY 2024 SNF VBP Program year.
#
# Note: SNFs that did not meet the SNFRM’s case minimum (25 or more eligible stays) in the performance period (FY 2022) are excluded from the SNF VBP Program for FY 2024. Payments to these SNFs in FY 2024 will not be affected by the SNF VBP Program; instead, these SNFs will receive their adjusted federal per diem rate. CMS will not publicly report any data for the FY 2024 SNF VBP Program year for these excluded SNFs.
#
#
# There is only one row.

# %% [markdown]
# ## Data Dictionary
#
# | Variable Name (Column Header) | Description | Variable Type |
# |---|---|---|
# | Baseline Period: FY 2019 National Average Readmission Rate | The SNF VBP Program's national unadjusted rate of unplanned readmissions in the baseline period (FY2019). | Numeric |
# | Performance Period: FY 2022 National Average Readmission Rate | The SNF VBP Program's national unadjusted rate of unplanned readmissions in the performance period (FY2022). | Numeric |
# | FY 2024 Achievement Threshold | The 25th percentile of national SNF performance on the SNF 30-Day All-Cause Readmission Measure (SNFRM) during the baseline period (FY 2019). This value was previously published in the FY 2022 SNF Prospective Payment System (PPS) final rule (86 FR 42513). | Numeric |
# | FY 2024 Benchmark | The mean of the top decile of national SNF performance on the SNFRM during the baseline period (FY 2019). This value was previously published in the FY 2022 SNF PPS final rule (86 FR 42513). | Numeric |
# | Range of Performance Scores | The range of SNF VBP Program performance scores for the FY 2024 SNF VBP Program year. | Numeric Range |
# | Total Number of SNFs Receiving Value-Based Incentive Payments | The total number of SNFs receiving SNF VBP Program value-based incentive payments in FY 2024. | Numeric |
# | Range of Incentive Payment Multipliers | The range of SNF VBP Program incentive payment multipliers for the FY 2024 SNF VBP Program year. | Numeric Range |
# | Range of Value-Based Incentive Payments (USD) | The range of SNF VBP Program value-based incentive payments paid to SNFs in FY 2024. | Dollar Range |
# | Total Amount of Value-Based Incentive Payments (USD) | The total amount of SNF VBP Program value-based incentive payments paid to SNFs in FY 2024. | Dollars |

# %%
file_path = qc.supporting_files_path + 'FY_2024_SNF_VBP_Aggregate_Performance.csv'
df, profile_df, numeric_summary = qc.analyze_csv_data_quality(file_path)
# Out:
# Loaded file successfully with encoding: utf-8
#
# ...
# DATASET OVERVIEW
# ...
# File: FY_2024_SNF_VBP_Aggregate_Performance.csv
# Rows: 1
# Columns: 9
#
# ...
# COLUMN NAMES AND DATA TYPES
# ...
#                                                   column_name   dtype
#    Baseline Period: FY 2019 National Average Readmission Rate float64
# Performance Period: FY 2022 National Average Readmission Rate float64
#                                 FY 2024 Achievement Threshold float64
#                                             FY 2024 Benchmark float64
#                                   Range of Performance Scores  object
# Total Number of SNFs Receiving Value-Based Incentive Payments   int64
#                        Range of Incentive Payment Multipliers  object
#                   Range of Value-Based Incentive Payments ($)  object
#            Total Amount of Value-Based Incentive Payments ($)  object
#
# ...
# DATASET-LEVEL QUALITY METRICS
# ...
# Duplicate rows: 0 (0.00%)
#
# ...
# COLUMN-LEVEL DATA QUALITY SUMMARY
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(profile_df)
# Out:
#                                          column_name    dtype  row_count  \
# 0  Baseline Period: FY 2019 National Average Read...  float64          1
# 1  Performance Period: FY 2022 National Average R...  float64          1
# 2                      FY 2024 Achievement Threshold  float64          1
# 3                                  FY 2024 Benchmark  float64          1
# 4                        Range of Performance Scores   object          1
# 5  Total Number of SNFs Receiving Value-Based Inc...    int64          1
# 6             Range of Incentive Payment Multipliers   object          1
# 7        Range of Value-Based Incentive Payments ($)   object          1
# 8  Total Amount of Value-Based Incentive Payments...   object          1
#
#    non_null_count  missing_count  missing_pct  completeness_pct  \
# 0               1              0          0.0             100.0
# 1               1              0          0.0             100.0
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(numeric_summary)
# Out:
#                                          column_name  count         mean  std  \
# 0  Baseline Period: FY 2019 National Average Read...    1.0      0.19788  NaN
# 1  Performance Period: FY 2022 National Average R...    1.0      0.20223  NaN
# 2                      FY 2024 Achievement Threshold    1.0      0.79271  NaN
# 3                                  FY 2024 Benchmark    1.0      0.83033  NaN
# 4  Total Number of SNFs Receiving Value-Based Inc...    1.0  10858.00000  NaN
#
#            min          25%          50%          75%          max
# 0      0.19788      0.19788      0.19788      0.19788      0.19788
# 1      0.20223      0.20223      0.20223      0.20223      0.20223
# 2      0.79271      0.79271      0.79271      0.79271      0.79271
# 3      0.83033      0.83033      0.83033      0.83033      0.83033
# 4  10858.00000  10858.00000  10858.00000  10858.00000  10858.00000
