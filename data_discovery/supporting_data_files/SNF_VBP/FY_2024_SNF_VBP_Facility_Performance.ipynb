# %% [markdown]
# ## NH Supporting File
#
#
# __FY_2024_SNF_VBP_Facility_Performance.csv__

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
import os

# Get the directory of the current file
current_dir = os.path.dirname(os.getcwd())

# Get the parent directory path
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))

# Add directory to sys.path
sys.path.insert(0, parent_dir)

import quality_check as qc

# %% [markdown]
# # Description
#
#
# This dataset contains facility-specific performance results for the fiscal year (FY) 2024 Skilled Nursing Facility Value-Based Purchasing (SNF VBP) Program. Included are baseline period (FY 2019) and performance period (FY 2022) risk-standardized readmission rates (RSRRs), achievement scores, improvement scores, and performance scores, rankings, and incentive payment multipliers for the FY 2024 SNF VBP Program year.
#
# Note: SNFs that did not meet the SNFRM’s case minimum (25 or more eligible stays) in the performance period (FY 2022) are excluded from the SNF VBP Program for FY 2024. Payments to these SNFs in FY 2024 will not be affected by the SNF VBP Program; instead, these SNFs will receive their adjusted federal per diem rate. CMS will not publicly report any data for the FY 2024 SNF VBP Program year for these excluded SNFs.
#
#
# The primary key is CMS Certification Number (CCN).

# %% [markdown]
# ## Data Dictionary
#
# | Variable Name (Column Header) | Description | Variable Type |
# |---|---|---|
# | SNF VBP Program Ranking | A skilled nursing facility's (SNF's) national rank among eligible, included SNFs in the SNF VBP Program. | Text |
# | Footnote -- SNF VBP Program Ranking | Footnote for the SNF VBP Program Ranking | Text |
# | CMS Certification Number (CCN) | Centers for Medicare & Medicaid Services (CMS) Certification Number (CCN) | Text (6) |
# | Provider Name | Provider name | Text |
# | Provider Address | Provider address | Text |
# | City/Town | Provider city/town | Text |
# | State | Provider state (2-digit postal code abbreviation) | Text (2) |
# | ZIP Code | Provider ZIP code | Numeric |
# | Baseline Period: FY 2019 Risk-Standardized Readmission Rate | A SNF's rate of unplanned readmissions in the baseline period (FY 2019), adjusted for stay-level risk factors such as clinical characteristics and comorbidities. | Text |
# | Footnote -- Baseline Period: FY 2019 Risk-Standardized Readmission Rate | Footnote for the Baseline Period: FY 2019 Risk-Standardized Readmission Rate | Text |
# | Performance Period: FY 2022 Risk-Standardized Readmission Rate | A SNF's rate of unplanned readmissions in the performance period (FY 2022), adjusted for stay-level risk factors such as clinical characteristics and comorbidities. | Numeric |
# | Footnote -- Performance Period: FY 2022 Risk-Standardized Readmission Rate | Footnote for the Performance Period: FY 2022 Risk-Standardized Readmission Rate | Text |
# | Achievement Score | A measure of how well a SNF performed during the performance period (FY 2022) compared with national SNF performance during the baseline period (FY 2019). Scores range from 0 to 100, with higher scores indicating better performance. | Numeric |
# | Footnote -- Achievement Score | Footnote for the Achievement score | Text |
# | Improvement Score | A measure of how much a SNF has improved from the baseline period (FY 2019) to the performance period (FY 2022). Scores range from 0 to 90, with higher scores indicating better performance. | Text |
# | Footnote -- Improvement Score | Footnote for the Improvement score | Text |
# | Performance Sore | The higher of a SNF's achievement score and improvement score. Scores range from 0 to 100, with higher scores indicating better performance. CMS uses this score to calculate incentive payment multipliers for the SNF VBP Program. | Numeric |
# | Footnote -- Performance Score | Footnote for the Performance score | Text |
# | Incentive Payment Multiplier | A multiplier assigned to a SNF based on its performance in the SNF VBP Program. When payments are made to a SNF's Medicare fee-for-service (FFS) Part A claims in FY 2024, CMS multiplies the SNF's adjusted federal per diem rate by this multiplier. | Numeric |
# | Footnote -- Incentive Payment Multiplier | Footnote for the Incentive Payment Multiplier | Text |

# %%
file_path = qc.supporting_files_path + 'FY_2024_SNF_VBP_Facility_Performance.csv'
df, profile_df, numeric_summary = qc.analyze_csv_data_quality(file_path)
# Out:
# Loaded file successfully with encoding: utf-8
#
# ...
# DATASET OVERVIEW
# ...
# File: FY_2024_SNF_VBP_Facility_Performance.csv
# Rows: 10858
# Columns: 20
#
# ...
# COLUMN NAMES AND DATA TYPES
# ...
#                                                                column_name   dtype
#                                                    SNF VBP Program Ranking   int64
#                                        Footnote -- SNF VBP Program Ranking float64
#                                             CMS Certification Number (CCN)   int64
#                                                              Provider Name  object
#                                                           Provider Address  object
#                                                                  City/Town  object
#                                                                      State  object
#                                                                   ZIP Code   int64
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(profile_df)
# Out:
#                                           column_name    dtype  row_count  \
# 0                             SNF VBP Program Ranking    int64      10858
# 1                 Footnote -- SNF VBP Program Ranking  float64      10858
# 2                      CMS Certification Number (CCN)    int64      10858
# 3                                       Provider Name   object      10858
# 4                                    Provider Address   object      10858
# 5                                           City/Town   object      10858
# 6                                               State   object      10858
# 7                                            ZIP Code    int64      10858
# 8   Baseline Period: FY 2019 Risk-Standardized Rea...   object      10858
# 9   Footnote -- Baseline Period: FY 2019 Risk-Stan...   object      10858
# 10  Performance Period: FY 2022 Risk-Standardized ...  float64      10858
# 11  Footnote -- Performance Period: FY 2022 Risk-S...  float64      10858
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(numeric_summary)
# Out:
#                                           column_name    count           mean  \
# 0                             SNF VBP Program Ranking  10858.0    4824.811107
# 1                 Footnote -- SNF VBP Program Ranking      0.0            NaN
# 2                      CMS Certification Number (CCN)  10858.0  292957.882115
# 3                                            ZIP Code  10858.0   47766.639897
# 4   Performance Period: FY 2022 Risk-Standardized ...  10858.0       0.202059
# 5   Footnote -- Performance Period: FY 2022 Risk-S...      0.0            NaN
# 6                                   Achievement Score  10858.0      29.999077
# 7                       Footnote -- Achievement Score      0.0            NaN
# 8                                   Performance Score  10858.0      31.872520
# 9                       Footnote -- Performance Score      0.0            NaN
# 10                       Incentive Payment Multiplier  10858.0       0.991538
# ...
